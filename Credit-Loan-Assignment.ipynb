# %% [markdown]
# <a href="https://colab.research.google.com/github/mmaruthi/ML-BootCamp-/blob/master/Credit-Loan-Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cca9eecb-e766-468a-b4f6-f3cd98cd6cf8" name="files[]" multiple disabled />
#      <output id="result-cca9eecb-e766-468a-b4f6-f3cd98cd6cf8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Bank_loan_dataset.csv to Bank_loan_dataset.csv

# %%
import numpy as np
import pandas as pd 

df = pd.read_csv("Bank_loan_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63999 entries, 0 to 63998
# Data columns (total 38 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   loan_amnt                   63999 non-null  int64
#  1   funded_amnt                 63999 non-null  int64
#  2   funded_amnt_inv             63999 non-null  float64
#  3   term                        63999 non-null  object
#  4   int_rate                    63999 non-null  float64
#  5   grade                       63999 non-null  object
#  6   sub_grade                   63999 non-null  object
#  7   emp_title                   63999 non-null  object
#  8   emp_length                  63999 non-null  object
#  9   home_ownership              63999 non-null  object
#  10  annual_inc                  63999 non-null  float64
#  11  verification_status         63999 non-null  object
#  12  pymnt_plan                  63999 non-null  object
# ...

# %%
df.head()
# Out:
#    loan_amnt  funded_amnt  ...  total_rev_hi_lim loan_status
# 0      14350        14350  ...           30800.0           0
# 1       4800         4800  ...           32900.0           0
# 2      10000        10000  ...           34900.0           0
# 3      15000        15000  ...           24700.0           0
# 4      16000        16000  ...           47033.0           0
#
# [5 rows x 38 columns]

# %%
df.shape
# Out:
# (63999, 38)

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 

df.loan_amnt.plot.hist()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# Above graph says that .. Loan amounts are ranging from 0 to 35000 dollars . Highest frequency range is in 5500 to 10000. And most people are applying in the range of 5000 to 20000.
#
# The same we shall see with a dist plot

# %%
sns.distplot(df.loan_amnt)

# %%
df.int_rate.plot.hist()

# %% [markdown]
# Interest rates are varying from a minimum of 5% to maximum of 30%.
#
# Let see the same with a distplot

# %%
sns.distplot(df.int_rate)

# %%
## Let us see if there is any correlation between loan_amnt and int_rate 
sns.scatterplot(df.int_rate,df.loan_amnt)

# %% [markdown]
# Above scatterplot says that .. At every interest rate , there are varying loan amounts i.e interest rate does not have or a direct relationship with Loan amount

# %%
df.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'pymnt_plan', 'purpose', 'title',
#        'zip_code', 'addr_state', 'dti', 'delinq_2yrs', 'inq_last_6mths',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'initial_list_status', 'total_rec_int', 'total_rec_late_fee',
#        'recoveries', 'collection_recovery_fee', 'collections_12_mths_ex_med',
#        'application_type', 'last_week_pay', 'acc_now_delinq', 'tot_coll_amt',
#        'tot_cur_bal', 'total_rev_hi_lim', 'loan_status'],
#       dtype='object')

# %%
## Let us see what relation does loan amount holds with annual income of the applicant ## 

sns.barplot(x="annual_inc",y="loan_amnt",data=df)
